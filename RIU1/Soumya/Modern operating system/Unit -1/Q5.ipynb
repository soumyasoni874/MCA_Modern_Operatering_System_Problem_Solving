# %%
import psutil

# Get network I/O statistics
net_stats = psutil.net_io_counters()

print(f"Bytes Sent     : {net_stats.bytes_sent} bytes")
print(f"Bytes Received : {net_stats.bytes_recv} bytes")
# Out:
# Bytes Sent     : 2295422 bytes
# Bytes Received : 2096592 bytes
